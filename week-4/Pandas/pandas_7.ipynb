# %% [markdown]
# # Import some 'braries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import the dataset by running this cell

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(url)

wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# # Delete the first, fourth, seventh, ninth, eleventh, thirteenth, and fourteenth columns

# %%
cols = []

# %%
cols.append(wine.columns[13])

# %%
cols
# Out:
# ['1', '2.43', '2.8', '.28', '5.64', '3.92', '1065']

# %%
for i in range(len(cols)):
    del wine[cols[i]]

# %%
wine
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# 5    14.39  1.87  14.6   96  2.52  1.98  1.02
# 6    14.06  2.15  17.6  121  2.51  1.25  1.06
# 7    14.83  1.64  14.0   97  2.98  1.98  1.08
# 8    13.86  1.35  16.0   98  3.15  1.85  1.01
# 9    14.10  2.16  18.0  105  3.32  2.38  1.25
# 10   14.12  1.48  16.8   95  2.43  1.57  1.17
# 11   13.75  1.73  16.0   89  2.76  1.81  1.15
# 12   14.75  1.73  11.4   91  3.69  2.81  1.25
# 13   14.38  1.87  12.0  102  3.64  2.96  1.20
# 14   13.63  1.81  17.2  112  2.91  1.46  1.28
# 15   14.30  1.92  20.0  120  3.14  1.97  1.07
# 16   13.83  1.57  20.0  115  3.40  1.72  1.13
# 17   14.19  1.59  16.5  108  3.93  1.86  1.23
# 18   13.64  3.10  15.2  116  3.03  1.66  0.96
# ...

# %% [markdown]
# # Assign the columns as below:
#
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins', 'hue']

# %%
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# # Set the values of the first 3 rows from the alcohol cloumn as NaN

# %%
wine.iloc[0:3,0].replace(np.nan)
# Out:
# 0    13.20
# 1    13.16
# 2    14.37
# Name: alcohol, dtype: float64

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.20        1.78               11.2        100        2.76
# 1      13.16        2.36               18.6        101        3.24
# 2      14.37        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# 5      14.39        1.87               14.6         96        2.52
# 6      14.06        2.15               17.6        121        2.51
# 7      14.83        1.64               14.0         97        2.98
# 8      13.86        1.35               16.0         98        3.15
# 9      14.10        2.16               18.0        105        3.32
# 10     14.12        1.48               16.8         95        2.43
# 11     13.75        1.73               16.0         89        2.76
# 12     14.75        1.73               11.4         91        3.69
# ...

# %% [markdown]
# # Set the values of rows 3 and 4 of magnesium as Nan

# %% [markdown]
# # Fill the value of Nan for the number 10 for alcohol and 100 for magnesium

# %%
wine.alcohol.fillna

# %% [markdown]
# # Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# # Create a array of 10 random numbers from 0 to 9... hint think numpy

# %% [markdown]
# # Use the array of random numbers as an index and assign NaN values to each corresponding row in the alcohol column

# %% [markdown]
# # How many missing values are there?

# %% [markdown]
# # Delete the rows tha contain missing values

# %% [markdown]
# # Print only the non-null values in acohol

# %% [markdown]
# # reset the index

# %% [markdown]
# # create a dataframe of wines with a hue < 7.5 in order of most to least alcoholic
